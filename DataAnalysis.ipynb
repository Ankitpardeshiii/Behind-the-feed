# %%
#collecting and dividing data into chunks
with open("initialdata.txt" , encoding = "utf-8" ) as f :
    data = f.read()
chunks = data.split("\n\n")
chunks = [ c for c in chunks if len(c)>3]

# %%
#Defining function to split data according to users
def parse_chunk(chunk):
    chunk = chunk.strip()
    sep_chunk = chunk.split("\n")
    username = sep_chunk[0]
    no_of_post = int(sep_chunk[1].split("post")[0].replace(",",""))
    no_of_followers =float(sep_chunk[2].split("followers")[0].replace(",", "").replace("K", "").replace("M", ""))
    if("K" in sep_chunk[2]):
        no_of_followers = int(no_of_followers * 1000)
    elif("M" in sep_chunk[2]):
        no_of_followers = int(no_of_followers * 1000000)
    else:
        no_of_followers = int(no_of_followers)
    no_of_following = float(sep_chunk[3].split("following")[0].replace(",","").replace("K","").replace("M",""))
    if("K" in sep_chunk[3]):
        no_of_following = int(no_of_following * 1000)
    elif("M" in sep_chunk[3]):
        no_of_following = int(no_of_following * 1000000)
    else:
        no_of_following = int(no_of_following)

    name = sep_chunk[4]
    if(len(sep_chunk)>5):
        category = sep_chunk[5]
        bio = "\n".join(sep_chunk[6])
    else:
        category = "unknown"
        bio = ""
    return { "Username" : username , "no_of_post" : no_of_post , "no_of_followers" : no_of_followers ,"no_of_following" : no_of_following, "Name" : name , "Category" : category , "Bio" : bio}
#Storing data into all chunks
all_chunk = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunk.append(parsed_chunk)

# %%
# Storing the cleaned and processed data into json file
import json
s = json.dumps(all_chunk ,indent =4)
with open("Punedata.json" ,"w") as f:
    f.write(s)

# %% [markdown]
# # Performing Data analysis

# %% [markdown]
# ## Finding user with most amount of followers

# %%
max = 0
for chunk in all_chunk:
    if(max<chunk["no_of_followers"]):
        max = chunk["no_of_followers"]
    chunk_with_max_followers = chunk
print("User with maximun followers is ",chunk_with_max_followers.get("Username"))
# Out:
# User with maximun followers is  katiasales2220

# %% [markdown]
# ## Finding user who follows most amount of people

# %%
max = 0
for chunk in all_chunk:
    if(max<chunk["no_of_following"]):
        max = chunk["no_of_following"]
    chunk_with_max_following = chunk
print("User with maximun following is ",chunk_with_max_followers.get("Username"))
# Out:
# User with maximun following is  katiasales2220

# %% [markdown]
# ## Counting different numbers of categories

# %%
no_of_categories = set()
for chunks in all_chunk :
    no_of_categories.add(chunks["Category"])
print(f"There are {len(no_of_categories)} in total")
# Out:
# There are 13 in total

# %% [markdown]
# # Conclusion

# %%
print("The User with maximun followers is ",chunk_with_max_followers.get("Username"))
print("User with maximun following is ",chunk_with_max_followers.get("Username"))
print(f"There are {len(no_of_categories)} in total")
# Out:
# The User with maximun followers is  katiasales2220
# User with maximun following is  katiasales2220
# There are 13 in total
